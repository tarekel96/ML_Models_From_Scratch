# %%
# import LinearRegression model
from linear_regression import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
# produce linear data
x = np.random.randint(100, size=100)/30 - 2
X = x.reshape(-1, 1)
# y = x + 2
y = x + 2 + 0.3*np.random.randn(100)

# %%
x.shape, y.shape
# Out:
# ((100,), (100,))

# %%
x = x.reshape(-1, 1)

# %%
x.shape
# Out:
# (100, 1)

# %%
fig, ax = plt.subplots()
ax.scatter(x,y, label='data points')
ax.set_title('Simple Linear Data')
# Out:
# Text(0.5, 1.0, 'Simple Linear Data')

# %%
lr_model = LinearRegression(epochs=100)

# %%
lr_model.fit(x, y)

# %%
lr_model.w
# Out:
# array([0.90327652, 1.65927778])

# %%
y_hat = lr_model.predict(x)

# %%
costs = lr_model.costs

# %%
fig, ax = plt.subplots()
ax.scatter(np.arange(1,101,1), costs)
ax.set_title('Gradient Descent')
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
fig, ax = plt.subplots()
ax.scatter(x,y, label='data points')
ax.plot(x,y_hat, c='red', label='regression line')
ax.set_title('LR Model predictions')
# Out:
# Text(0.5, 1.0, 'LR Model predictions')

# %%
lr_model_2 = LinearRegression(epochs=1000)

# %%
lr_model_2.fit(x, y)

# %%
y_hat_2 = lr_model_2.predict(x)

# %%
costs_2 = lr_model_2.costs

# %%
fig, ax = plt.subplots()
ax.scatter(np.arange(1,1001,1), costs_2)
ax.set_title('Gradient Descent')
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
fig, ax = plt.subplots()
ax.scatter(x,y, label='data points')
ax.plot(x,y_hat_2, c='red', label='regression line')
ax.set_title('LR Model predictions')
# Out:
# Text(0.5, 1.0, 'LR Model predictions')
